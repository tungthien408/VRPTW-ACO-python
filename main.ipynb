# %%
import pandas as pd
import matplotlib.pyplot as plt

from vrptw_base import VrptwGraph
from basic_aco import BasicACO

# %%
file_path = './dataset/homberger_200_customer_instances/R1_2_1.txt'
# file_path = './dataset/solomon_25/R101.txt'
result_path = './results/param4/r1/'
filename = 'aco_results_200.csv'

ants_num = 20
max_iter = 200
alpha = 1
beta = 2
rho = 0.1
q0 = 0.1
show_figure = False 

graph = VrptwGraph(file_path, rho=rho)
basic_aco = BasicACO(graph, ants_num=ants_num, max_iter=max_iter, beta=beta, q0=q0, result_path=result_path, filename=filename,
                     whether_or_not_to_show_figure=show_figure)

basic_aco.run_basic_aco()
# Out:
# Total nodes parsed: 201
# First node: ['0', '70', '70', '0', '0', '634', '0']
#
#
# [iteration 0]: find a improved path, its distance is 12517.161664
# it takes 1.165 second multiple_ant_colony_system running
#
#
# [iteration 1]: find a improved path, its distance is 10933.014593
# it takes 2.380 second multiple_ant_colony_system running
#
#
# [iteration 2]: find a improved path, its distance is 10034.266141
# it takes 3.382 second multiple_ant_colony_system running
#
#
# [iteration 3]: find a improved path, its distance is 9764.066713
# it takes 4.336 second multiple_ant_colony_system running
#
#
# [iteration 4]: find a improved path, its distance is 9607.689902
# it takes 5.278 second multiple_ant_colony_system running
#
#
# [iteration 5]: find a improved path, its distance is 9397.921673
# it takes 6.206 second multiple_ant_colony_system running
#
#
# [iteration 6]: find a improved path, its distance is 9180.202198
# it takes 7.121 second multiple_ant_colony_system running
#
#
# [iteration 8]: find a improved path, its distance is 9030.113328
# it takes 8.945 second multiple_ant_colony_system running
#
#
# [iteration 10]: find a improved path, its distance is 8877.962047
# it takes 10.873 second multiple_ant_colony_system running
#
#
# [iteration 12]: find a improved path, its distance is 8862.491763
# it takes 12.833 second multiple_ant_colony_system running
#
#
# [iteration 14]: find a improved path, its distance is 8834.286329
# it takes 14.707 second multiple_ant_colony_system running
#
#
# [iteration 15]: find a improved path, its distance is 8764.487583
# it takes 15.594 second multiple_ant_colony_system running
#
#
# [iteration 16]: find a improved path, its distance is 8756.980593
# it takes 16.477 second multiple_ant_colony_system running
#
#
# [iteration 17]: find a improved path, its distance is 8727.811995
# it takes 17.345 second multiple_ant_colony_system running
#
#
# [iteration 18]: find a improved path, its distance is 8387.548481
# it takes 18.205 second multiple_ant_colony_system running
#
#
# [iteration 24]: find a improved path, its distance is 8301.748266
# it takes 23.273 second multiple_ant_colony_system running
#
#
# [iteration 25]: find a improved path, its distance is 8206.072771
# it takes 24.119 second multiple_ant_colony_system running
#
#
# [iteration 31]: find a improved path, its distance is 8144.574648
# it takes 29.100 second multiple_ant_colony_system running
#
#
# [iteration 32]: find a improved path, its distance is 8082.021256
# it takes 29.914 second multiple_ant_colony_system running
#
#
# [iteration 39]: find a improved path, its distance is 8044.970820
# it takes 35.644 second multiple_ant_colony_system running
#
#
# [iteration 40]: find a improved path, its distance is 7965.897971
# it takes 36.476 second multiple_ant_colony_system running
#
#
# [iteration 41]: find a improved path, its distance is 7850.957573
# it takes 37.284 second multiple_ant_colony_system running
#
#
# [iteration 44]: find a improved path, its distance is 7769.670630
# it takes 39.691 second multiple_ant_colony_system running
#
#
# [iteration 49]: find a improved path, its distance is 7745.373650
# it takes 43.671 second multiple_ant_colony_system running
#
#
# [iteration 57]: find a improved path, its distance is 7690.894572
# it takes 50.075 second multiple_ant_colony_system running
#
#
# [iteration 59]: find a improved path, its distance is 7666.585403
# it takes 51.656 second multiple_ant_colony_system running
#
#
# [iteration 63]: find a improved path, its distance is 7653.491454
# it takes 54.854 second multiple_ant_colony_system running
#
#
# [iteration 70]: find a improved path, its distance is 7622.738740
# it takes 60.329 second multiple_ant_colony_system running
#
#
# [iteration 71]: find a improved path, its distance is 7613.230156
# it takes 61.111 second multiple_ant_colony_system running
#
#
# [iteration 73]: find a improved path, its distance is 7612.448619
# it takes 62.651 second multiple_ant_colony_system running
#
#
# [iteration 75]: find a improved path, its distance is 7571.090250
# it takes 64.198 second multiple_ant_colony_system running
#
#
# [iteration 77]: find a improved path, its distance is 7540.022511
# it takes 65.726 second multiple_ant_colony_system running
#
#
# [iteration 81]: find a improved path, its distance is 7476.049824
# it takes 68.794 second multiple_ant_colony_system running
#
#
# [iteration 86]: find a improved path, its distance is 7390.317207
# it takes 72.707 second multiple_ant_colony_system running
#
#
# [iteration 99]: find a improved path, its distance is 7339.066823
# it takes 82.684 second multiple_ant_colony_system running
#
#
# [iteration 110]: find a improved path, its distance is 7304.968144
# it takes 91.076 second multiple_ant_colony_system running
#
#
# [iteration 114]: find a improved path, its distance is 7253.592762
# it takes 94.115 second multiple_ant_colony_system running
#
#
# [iteration 120]: find a improved path, its distance is 7251.766848
# it takes 98.678 second multiple_ant_colony_system running
#
#
# [iteration 124]: find a improved path, its distance is 7180.654920
# it takes 101.734 second multiple_ant_colony_system running
#
#
# [iteration 131]: find a improved path, its distance is 7168.225664
# it takes 107.160 second multiple_ant_colony_system running
#
#
# [iteration 133]: find a improved path, its distance is 7088.358103
# it takes 108.710 second multiple_ant_colony_system running
#
#
# [iteration 136]: find a improved path, its distance is 7072.546364
# it takes 110.962 second multiple_ant_colony_system running
#
#
# [iteration 144]: find a improved path, its distance is 7055.244746
# it takes 116.989 second multiple_ant_colony_system running
#
#
# [iteration 149]: find a improved path, its distance is 6942.957765
# it takes 120.714 second multiple_ant_colony_system running
#
#
# final best path distance is 6942.957765, number of vehicle is 46
# it takes 174.986 second multiple_ant_colony_system running
# Results saved to aco_results_200.csv

# %%
result_file = './results/param4/r1/aco_results_200.csv'
df = pd.read_csv(result_file)

plt.figure(figsize=(12, 6))

plt.plot(df['iteration'], df['best_cost'], 
         linewidth=2, color='blue', label='Best Cost')

plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Cost (Distance)', fontsize=12)
plt.title('ACO Convergence - Best Cost over Iterations', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
