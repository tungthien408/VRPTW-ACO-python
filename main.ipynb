# %%
import pandas as pd
import matplotlib.pyplot as plt

from vrptw_base import VrptwGraph
from basic_aco import BasicACO

# %%
file_path = './dataset/homberger_800_customer_instances/C1_8_1.txt'
result_path = './results/param4/'
filename = 'aco_results_800.csv'

ants_num = 20
max_iter = 200
beta = 2
q0 = 0.1
show_figure = False 

graph = VrptwGraph(file_path)
basic_aco = BasicACO(graph, ants_num=ants_num, max_iter=max_iter, beta=beta, q0=q0, result_path=result_path, filename=filename,
                     whether_or_not_to_show_figure=show_figure)

basic_aco.run_basic_aco()
# Out:
# Total nodes parsed: 601
# First node: ['0', '150', '150', '0', '0', '1496', '0']
#
#
# [iteration 0]: find a improved path, its distance is 60896.403973
# it takes 8.446 second multiple_ant_colony_system running
#
#
# [iteration 1]: find a improved path, its distance is 46978.777104
# it takes 16.444 second multiple_ant_colony_system running
#
#
# [iteration 2]: find a improved path, its distance is 41453.382206
# it takes 23.921 second multiple_ant_colony_system running
#
#
# [iteration 3]: find a improved path, its distance is 39597.654117
# it takes 31.005 second multiple_ant_colony_system running
#
#
# [iteration 4]: find a improved path, its distance is 38158.825181
# it takes 38.382 second multiple_ant_colony_system running
#
#
# [iteration 5]: find a improved path, its distance is 36563.523425
# it takes 45.412 second multiple_ant_colony_system running
#
#
# [iteration 6]: find a improved path, its distance is 35331.351043
# it takes 52.201 second multiple_ant_colony_system running
#
#
# [iteration 7]: find a improved path, its distance is 34503.091039
# it takes 59.166 second multiple_ant_colony_system running
#
#
# [iteration 8]: find a improved path, its distance is 33416.655298
# it takes 65.970 second multiple_ant_colony_system running
#
#
# [iteration 9]: find a improved path, its distance is 32337.627224
# it takes 72.551 second multiple_ant_colony_system running
#
#
# [iteration 11]: find a improved path, its distance is 31782.546715
# it takes 85.882 second multiple_ant_colony_system running
#
#
# [iteration 12]: find a improved path, its distance is 31191.242509
# it takes 92.447 second multiple_ant_colony_system running
#
#
# [iteration 14]: find a improved path, its distance is 30763.288260
# it takes 105.622 second multiple_ant_colony_system running
#
#
# [iteration 16]: find a improved path, its distance is 30542.668595
# it takes 118.575 second multiple_ant_colony_system running
#
#
# [iteration 17]: find a improved path, its distance is 30523.026996
# it takes 125.214 second multiple_ant_colony_system running
#
#
# [iteration 18]: find a improved path, its distance is 29965.274805
# it takes 131.842 second multiple_ant_colony_system running
#
#
# [iteration 20]: find a improved path, its distance is 29934.322355
# it takes 144.627 second multiple_ant_colony_system running
#
#
# [iteration 23]: find a improved path, its distance is 29132.553664
# it takes 166.475 second multiple_ant_colony_system running
#
#
# [iteration 24]: find a improved path, its distance is 28859.205569
# it takes 174.526 second multiple_ant_colony_system running
#
#
# [iteration 27]: find a improved path, its distance is 28635.963074
# it takes 195.949 second multiple_ant_colony_system running
#
#
# [iteration 31]: find a improved path, its distance is 27846.068483
# it takes 217.087 second multiple_ant_colony_system running
#
#
# [iteration 38]: find a improved path, its distance is 27759.378706
# it takes 255.375 second multiple_ant_colony_system running
#
#
# [iteration 40]: find a improved path, its distance is 27632.404662
# it takes 267.071 second multiple_ant_colony_system running
#
#
# [iteration 43]: find a improved path, its distance is 27531.138758
# it takes 286.333 second multiple_ant_colony_system running
#
#
# [iteration 44]: find a improved path, its distance is 27526.148486
# it takes 292.370 second multiple_ant_colony_system running
#
#
# [iteration 45]: find a improved path, its distance is 27498.178526
# it takes 298.419 second multiple_ant_colony_system running
#
#
# [iteration 54]: find a improved path, its distance is 27277.762776
# it takes 354.847 second multiple_ant_colony_system running
#
#
# [iteration 57]: find a improved path, its distance is 27269.387287
# it takes 373.557 second multiple_ant_colony_system running
#
#
# [iteration 59]: find a improved path, its distance is 26732.467700
# it takes 385.633 second multiple_ant_colony_system running
#
#
# [iteration 69]: find a improved path, its distance is 26656.211021
# it takes 443.137 second multiple_ant_colony_system running
#
#
# [iteration 72]: find a improved path, its distance is 26598.194158
# it takes 460.371 second multiple_ant_colony_system running
#
#
# [iteration 82]: find a improved path, its distance is 26464.495054
# it takes 519.797 second multiple_ant_colony_system running
#
#
# [iteration 88]: find a improved path, its distance is 26364.967053
# it takes 555.627 second multiple_ant_colony_system running
#
#
# [iteration 97]: find a improved path, its distance is 26077.183772
# it takes 609.701 second multiple_ant_colony_system running
#
#
# [iteration 106]: find a improved path, its distance is 25887.554263
# it takes 664.119 second multiple_ant_colony_system running
#
#
# [iteration 149]: find a improved path, its distance is 25780.960049
# it takes 899.728 second multiple_ant_colony_system running
#
#
# final best path distance is 25780.960049, number of vehicle is 102
# it takes 1183.120 second multiple_ant_colony_system running
# Results saved to aco_results_800.csv

# %%
result_file = './results/param4/aco_results_800.csv'
df = pd.read_csv(result_file)

plt.figure(figsize=(12, 6))

plt.plot(df['iteration'], df['best_cost'], 
         linewidth=2, color='blue', label='Best Cost')

plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Cost (Distance)', fontsize=12)
plt.title('ACO Convergence - Best Cost over Iterations', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
