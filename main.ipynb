# %%
import pandas as pd
import matplotlib.pyplot as plt

from vrptw_base import VrptwGraph
from basic_aco import BasicACO

# %%
# file_path = './dataset/homberger_200_customer_instances/R1_2_1.txt'
input_path = './dataset/'
result_path = './results/param4/rc/rc2/'

file_path_solomon = ['solomon_25/', 'solomon_50/', 'solomon-100/']
file_path_homberger = [
    'homberger_200_customer_instances/', 
    'homberger_400_customer_instances/', 
    'homberger_600_customer_instances/', 
    'homberger_800_customer_instances/', 
    'homberger_1000_customer_instances/'
    ]
input_filename_solomon = 'rc201.txt'
input_filename_homberger = [
    'RC2_2_1.txt', 
    'RC2_4_1.txt', 
    'RC2_6_1.txt', 
    'RC2_8_1.txt', 
    'RC2_10_1.txt'
    ]
output_filename_solomon = ['aco_results_25.csv', 'aco_results_50.csv', 'aco_results_100.csv']
output_filename_homberger = [
    'aco_results_200.csv', 
    'aco_results_400.csv', 
    'aco_results_600.csv', 
    'aco_results_800.csv', 
    'aco_results_1000.csv'
    ]

ants_num = 20
max_iter = 200
alpha = 1
beta = 2
rho = 0.1
q0 = 0.1
show_figure = False 

# solomon
for filepath, filename in zip(file_path_solomon, output_filename_solomon):
    file_path = input_path + filepath + input_filename_solomon
    graph = VrptwGraph(file_path, rho=rho)
    basic_aco = BasicACO(graph, ants_num=ants_num, max_iter=max_iter, beta=beta, q0=q0, result_path=result_path, filename=filename,
                     whether_or_not_to_show_figure=show_figure)
    basic_aco.run_basic_aco()
# homberger
for filepath, input_filename, output_filename in zip(file_path_homberger, input_filename_homberger, output_filename_homberger):
    file_path = input_path + filepath + input_filename
    graph = VrptwGraph(file_path, rho=rho)
    basic_aco = BasicACO(graph, ants_num=ants_num, max_iter=max_iter, beta=beta, q0=q0, result_path=result_path, filename=output_filename,
                     whether_or_not_to_show_figure=show_figure)
    basic_aco.run_basic_aco()


# basic_aco.run_basic_aco()
# Out:
# Line 36: '' -> parts: [] (SKIPPING)
#
# Total nodes parsed: 26
# First node: ['0', '40', '50', '0', '0', '960', '0']
#
#
# [iteration 0]: find a improved path, its distance is 728.673952
# it takes 0.057 second multiple_ant_colony_system running
#
#
# [iteration 1]: find a improved path, its distance is 712.777165
# it takes 0.102 second multiple_ant_colony_system running
#
#
# [iteration 2]: find a improved path, its distance is 609.409994
# it takes 0.148 second multiple_ant_colony_system running
#
#
# [iteration 3]: find a improved path, its distance is 522.205177
# it takes 0.185 second multiple_ant_colony_system running
#
#
# [iteration 5]: find a improved path, its distance is 489.308164
# it takes 0.296 second multiple_ant_colony_system running
#
#
# [iteration 6]: find a improved path, its distance is 483.279624
# it takes 0.359 second multiple_ant_colony_system running
#
#
# [iteration 7]: find a improved path, its distance is 459.300648
# it takes 0.403 second multiple_ant_colony_system running
#
#
# [iteration 9]: find a improved path, its distance is 456.880639
# it takes 0.479 second multiple_ant_colony_system running
#
#
# [iteration 12]: find a improved path, its distance is 453.676271
# it takes 0.588 second multiple_ant_colony_system running
#
#
# [iteration 15]: find a improved path, its distance is 423.875211
# it takes 0.701 second multiple_ant_colony_system running
#
#
# [iteration 21]: find a improved path, its distance is 420.831760
# it takes 0.935 second multiple_ant_colony_system running
#
#
# [iteration 24]: find a improved path, its distance is 420.831760
# it takes 1.063 second multiple_ant_colony_system running
#
#
# [iteration 30]: find a improved path, its distance is 420.831760
# it takes 1.296 second multiple_ant_colony_system running
#
#
# iteration exit: can not find better solution in 100 iteration
#
#
# final best path distance is 420.831760, number of vehicle is 4
# it takes 5.150 second multiple_ant_colony_system running
# Results saved to aco_results_25.csv
# Line 61: '' -> parts: [] (SKIPPING)
# Line 62: '' -> parts: [] (SKIPPING)
#
# Total nodes parsed: 51
# First node: ['0', '40', '50', '0', '0', '960', '0']
#
#
# [iteration 0]: find a improved path, its distance is 1789.849497
# it takes 0.128 second multiple_ant_colony_system running
#
#
# [iteration 1]: find a improved path, its distance is 1610.342279
# it takes 0.238 second multiple_ant_colony_system running
#
#
# [iteration 2]: find a improved path, its distance is 1468.611774
# it takes 0.352 second multiple_ant_colony_system running
#
#
# [iteration 3]: find a improved path, its distance is 1356.898705
# it takes 0.449 second multiple_ant_colony_system running
#
#
# [iteration 5]: find a improved path, its distance is 1290.048637
# it takes 0.654 second multiple_ant_colony_system running
#
#
# [iteration 7]: find a improved path, its distance is 1204.872983
# it takes 0.855 second multiple_ant_colony_system running
#
#
# [iteration 11]: find a improved path, its distance is 1165.622474
# it takes 1.268 second multiple_ant_colony_system running
#
#
# [iteration 12]: find a improved path, its distance is 1111.475954
# it takes 1.369 second multiple_ant_colony_system running
#
#
# [iteration 15]: find a improved path, its distance is 1075.249304
# it takes 1.665 second multiple_ant_colony_system running
#
#
# [iteration 25]: find a improved path, its distance is 1028.787790
# it takes 2.598 second multiple_ant_colony_system running
#
#
# [iteration 34]: find a improved path, its distance is 1015.049479
# it takes 3.398 second multiple_ant_colony_system running
#
#
# [iteration 49]: find a improved path, its distance is 986.275253
# it takes 4.692 second multiple_ant_colony_system running
#
#
# [iteration 53]: find a improved path, its distance is 986.275253
# it takes 5.048 second multiple_ant_colony_system running
#
#
# [iteration 57]: find a improved path, its distance is 953.785844
# it takes 5.413 second multiple_ant_colony_system running
#
#
# [iteration 65]: find a improved path, its distance is 949.117686
# it takes 6.104 second multiple_ant_colony_system running
#
#
# [iteration 67]: find a improved path, its distance is 949.117686
# it takes 6.268 second multiple_ant_colony_system running
#
#
# [iteration 100]: find a improved path, its distance is 949.117686
# it takes 9.048 second multiple_ant_colony_system running
#
#
# [iteration 180]: find a improved path, its distance is 949.117686
# it takes 15.524 second multiple_ant_colony_system running
#
#
# final best path distance is 949.117686, number of vehicle is 8
# it takes 17.067 second multiple_ant_colony_system running
# Results saved to aco_results_50.csv
#
# Total nodes parsed: 101
# First node: ['0', '40', '50', '0', '0', '960', '0']
#
#
# [iteration 0]: find a improved path, its distance is 3229.276986
# it takes 0.317 second multiple_ant_colony_system running
#
#
# [iteration 1]: find a improved path, its distance is 2888.333845
# it takes 0.611 second multiple_ant_colony_system running
#
#
# [iteration 2]: find a improved path, its distance is 2566.794920
# it takes 0.918 second multiple_ant_colony_system running
#
#
# [iteration 3]: find a improved path, its distance is 2546.259575
# it takes 1.243 second multiple_ant_colony_system running
#
#
# [iteration 4]: find a improved path, its distance is 2456.598630
# it takes 1.508 second multiple_ant_colony_system running
#
#
# [iteration 5]: find a improved path, its distance is 2251.693545
# it takes 1.773 second multiple_ant_colony_system running
#
#
# [iteration 6]: find a improved path, its distance is 2133.835422
# it takes 2.028 second multiple_ant_colony_system running
#
#
# [iteration 9]: find a improved path, its distance is 2004.834922
# it takes 2.794 second multiple_ant_colony_system running
#
#
# [iteration 36]: find a improved path, its distance is 1971.195130
# it takes 11.142 second multiple_ant_colony_system running
#
#
# [iteration 42]: find a improved path, its distance is 1953.384147
# it takes 13.677 second multiple_ant_colony_system running
#
#
# [iteration 55]: find a improved path, its distance is 1912.758338
# it takes 18.765 second multiple_ant_colony_system running
#
#
# [iteration 57]: find a improved path, its distance is 1884.910922
# it takes 19.494 second multiple_ant_colony_system running
#
#
# [iteration 77]: find a improved path, its distance is 1884.406284
# it takes 26.669 second multiple_ant_colony_system running
#
#
# [iteration 78]: find a improved path, its distance is 1868.442751
# it takes 27.027 second multiple_ant_colony_system running
#
#
# [iteration 80]: find a improved path, its distance is 1844.705306
# it takes 27.789 second multiple_ant_colony_system running
#
#
# [iteration 84]: find a improved path, its distance is 1839.883150
# it takes 29.446 second multiple_ant_colony_system running
#
#
# [iteration 90]: find a improved path, its distance is 1777.143983
# it takes 31.613 second multiple_ant_colony_system running
#
#
# iteration exit: can not find better solution in 100 iteration
#
#
# final best path distance is 1777.143983, number of vehicle is 15
# it takes 68.556 second multiple_ant_colony_system running
# Results saved to aco_results_100.csv
#
# Total nodes parsed: 201
# First node: ['0', '70', '70', '0', '0', '2535', '0']
#
#
# [iteration 0]: find a improved path, its distance is 8894.580890
# it takes 1.490 second multiple_ant_colony_system running
#
#
# [iteration 1]: find a improved path, its distance is 7958.462641
# it takes 2.733 second multiple_ant_colony_system running
#
#
# [iteration 2]: find a improved path, its distance is 7347.145774
# it takes 4.038 second multiple_ant_colony_system running
#
#
# [iteration 3]: find a improved path, its distance is 6982.743090
# it takes 5.343 second multiple_ant_colony_system running
#
#
# [iteration 4]: find a improved path, its distance is 6646.871717
# it takes 6.535 second multiple_ant_colony_system running
#
#
# [iteration 5]: find a improved path, its distance is 6415.064152
# it takes 7.866 second multiple_ant_colony_system running
#
#
# [iteration 6]: find a improved path, its distance is 6313.650681
# it takes 9.164 second multiple_ant_colony_system running
#
#
# [iteration 8]: find a improved path, its distance is 5982.801935
# it takes 11.586 second multiple_ant_colony_system running
#
#
# [iteration 10]: find a improved path, its distance is 5924.177548
# it takes 13.974 second multiple_ant_colony_system running
#
#
# [iteration 12]: find a improved path, its distance is 5882.907894
# it takes 16.104 second multiple_ant_colony_system running
#
#
# [iteration 14]: find a improved path, its distance is 5580.271651
# it takes 18.352 second multiple_ant_colony_system running
#
#
# [iteration 15]: find a improved path, its distance is 5567.117875
# it takes 19.597 second multiple_ant_colony_system running
#
#
# [iteration 19]: find a improved path, its distance is 5508.137610
# it takes 24.059 second multiple_ant_colony_system running
#
#
# [iteration 20]: find a improved path, its distance is 5493.042860
# it takes 25.253 second multiple_ant_colony_system running
#
#
# [iteration 21]: find a improved path, its distance is 5198.519590
# it takes 26.434 second multiple_ant_colony_system running
#
#
# [iteration 29]: find a improved path, its distance is 5193.348073
# it takes 34.471 second multiple_ant_colony_system running
#
#
# [iteration 33]: find a improved path, its distance is 4981.288954
# it takes 38.410 second multiple_ant_colony_system running
#
#
# [iteration 45]: find a improved path, its distance is 4977.023615
# it takes 50.265 second multiple_ant_colony_system running
#
#
# [iteration 47]: find a improved path, its distance is 4927.668341
# it takes 52.314 second multiple_ant_colony_system running
#
#
# [iteration 48]: find a improved path, its distance is 4904.455263
# it takes 53.341 second multiple_ant_colony_system running
#
#
# [iteration 49]: find a improved path, its distance is 4897.245859
# it takes 54.389 second multiple_ant_colony_system running
#
#
# [iteration 53]: find a improved path, its distance is 4802.728667
# it takes 58.307 second multiple_ant_colony_system running
#
#
# [iteration 55]: find a improved path, its distance is 4654.534235
# it takes 60.254 second multiple_ant_colony_system running
#
#
# [iteration 86]: find a improved path, its distance is 4635.701824
# it takes 89.371 second multiple_ant_colony_system running
#
#
# [iteration 90]: find a improved path, its distance is 4593.227558
# it takes 93.457 second multiple_ant_colony_system running
#
#
# [iteration 97]: find a improved path, its distance is 4588.638798
# it takes 100.378 second multiple_ant_colony_system running
#
#
# [iteration 107]: find a improved path, its distance is 4577.570836
# it takes 110.952 second multiple_ant_colony_system running
#
#
# [iteration 115]: find a improved path, its distance is 4557.435768
# it takes 118.698 second multiple_ant_colony_system running
#
#
# [iteration 117]: find a improved path, its distance is 4551.106328
# it takes 120.775 second multiple_ant_colony_system running
#
#
# [iteration 121]: find a improved path, its distance is 4512.467808
# it takes 124.938 second multiple_ant_colony_system running
#
#
# [iteration 147]: find a improved path, its distance is 4506.148008
# it takes 149.393 second multiple_ant_colony_system running
#
#
# [iteration 165]: find a improved path, its distance is 4503.749330
# it takes 165.775 second multiple_ant_colony_system running
#
#
# [iteration 176]: find a improved path, its distance is 4465.635060
# it takes 175.824 second multiple_ant_colony_system running
#
#
# final best path distance is 4465.635060, number of vehicle is 24
# it takes 197.329 second multiple_ant_colony_system running
# Results saved to aco_results_200.csv
#
# Total nodes parsed: 401
# First node: ['0', '100', '100', '0', '0', '3060', '0']
#
#
# [iteration 0]: find a improved path, its distance is 26152.452189
# it takes 3.949 second multiple_ant_colony_system running
#
#
# [iteration 1]: find a improved path, its distance is 22576.005808
# it takes 6.958 second multiple_ant_colony_system running
#
#
# [iteration 2]: find a improved path, its distance is 20213.832770
# it takes 9.893 second multiple_ant_colony_system running
#
#
# [iteration 3]: find a improved path, its distance is 19524.168995
# it takes 13.589 second multiple_ant_colony_system running
#
#
# [iteration 4]: find a improved path, its distance is 18762.536760
# it takes 16.672 second multiple_ant_colony_system running
#
#
# [iteration 5]: find a improved path, its distance is 18550.516890
# it takes 19.387 second multiple_ant_colony_system running
#
#
# [iteration 6]: find a improved path, its distance is 18055.648578
# it takes 22.029 second multiple_ant_colony_system running
#
#
# [iteration 7]: find a improved path, its distance is 17300.035005
# it takes 24.594 second multiple_ant_colony_system running
#
#
# [iteration 8]: find a improved path, its distance is 16739.367864
# it takes 27.100 second multiple_ant_colony_system running
#
#
# [iteration 9]: find a improved path, its distance is 16585.808774
# it takes 29.593 second multiple_ant_colony_system running
#
#
# [iteration 10]: find a improved path, its distance is 15727.481065
# it takes 32.053 second multiple_ant_colony_system running
#
#
# [iteration 14]: find a improved path, its distance is 15221.338781
# it takes 45.386 second multiple_ant_colony_system running
#
#
# [iteration 19]: find a improved path, its distance is 15061.219247
# it takes 60.772 second multiple_ant_colony_system running
#
#
# [iteration 24]: find a improved path, its distance is 14600.932390
# it takes 77.301 second multiple_ant_colony_system running
#
#
# [iteration 25]: find a improved path, its distance is 14476.322888
# it takes 80.744 second multiple_ant_colony_system running
#
#
# [iteration 26]: find a improved path, its distance is 14382.917679
# it takes 84.083 second multiple_ant_colony_system running
#
#
# [iteration 28]: find a improved path, its distance is 14202.928961
# it takes 91.281 second multiple_ant_colony_system running
#
#
# [iteration 30]: find a improved path, its distance is 14031.738785
# it takes 98.020 second multiple_ant_colony_system running
#
#
# [iteration 33]: find a improved path, its distance is 13735.067989
# it takes 107.645 second multiple_ant_colony_system running
#
#
# [iteration 34]: find a improved path, its distance is 13513.920053
# it takes 110.602 second multiple_ant_colony_system running
#
#
# [iteration 48]: find a improved path, its distance is 13304.290452
# it takes 155.236 second multiple_ant_colony_system running
#
#
# [iteration 50]: find a improved path, its distance is 13199.859275
# it takes 161.762 second multiple_ant_colony_system running
#
#
# [iteration 61]: find a improved path, its distance is 13152.630430
# it takes 199.639 second multiple_ant_colony_system running
#
#
# [iteration 63]: find a improved path, its distance is 13015.737400
# it takes 205.783 second multiple_ant_colony_system running
#
#
# [iteration 66]: find a improved path, its distance is 12842.100769
# it takes 215.217 second multiple_ant_colony_system running
#
#
# [iteration 74]: find a improved path, its distance is 12796.791626
# it takes 239.501 second multiple_ant_colony_system running
#
#
# [iteration 77]: find a improved path, its distance is 12514.951016
# it takes 248.338 second multiple_ant_colony_system running
#
#
# [iteration 105]: find a improved path, its distance is 12442.022050
# it takes 355.092 second multiple_ant_colony_system running
#
#
# [iteration 106]: find a improved path, its distance is 12319.286623
# it takes 357.940 second multiple_ant_colony_system running
#
#
# [iteration 112]: find a improved path, its distance is 12300.075968
# it takes 374.907 second multiple_ant_colony_system running
#
#
# [iteration 123]: find a improved path, its distance is 12219.126811
# it takes 406.502 second multiple_ant_colony_system running
#
#
# [iteration 124]: find a improved path, its distance is 12176.329805
# it takes 409.351 second multiple_ant_colony_system running
#
#
# [iteration 136]: find a improved path, its distance is 12128.216137
# it takes 447.635 second multiple_ant_colony_system running
#
#
# [iteration 140]: find a improved path, its distance is 12071.928292
# it takes 460.652 second multiple_ant_colony_system running
#
#
# [iteration 171]: find a improved path, its distance is 12043.379765
# it takes 551.434 second multiple_ant_colony_system running
#
#
# [iteration 182]: find a improved path, its distance is 12030.664055
# it takes 587.370 second multiple_ant_colony_system running
#
#
# [iteration 187]: find a improved path, its distance is 12003.087455
# it takes 602.599 second multiple_ant_colony_system running
#
#
# [iteration 191]: find a improved path, its distance is 11978.558091
# it takes 614.545 second multiple_ant_colony_system running
#
#
# [iteration 195]: find a improved path, its distance is 11958.821979
# it takes 626.793 second multiple_ant_colony_system running
#
#
# [iteration 196]: find a improved path, its distance is 11906.611361
# it takes 629.861 second multiple_ant_colony_system running
#
#
# final best path distance is 11906.611361, number of vehicle is 47
# it takes 639.130 second multiple_ant_colony_system running
# Results saved to aco_results_400.csv
#
# Total nodes parsed: 601
# First node: ['0', '150', '150', '0', '0', '4823', '0']
#
#
# [iteration 0]: find a improved path, its distance is 55411.805150
# it takes 8.899 second multiple_ant_colony_system running
#
#
# [iteration 1]: find a improved path, its distance is 44984.625506
# it takes 17.286 second multiple_ant_colony_system running
#
#
# [iteration 2]: find a improved path, its distance is 43003.101220
# it takes 25.258 second multiple_ant_colony_system running
#
#
# [iteration 3]: find a improved path, its distance is 41423.093034
# it takes 33.106 second multiple_ant_colony_system running
#
#
# [iteration 4]: find a improved path, its distance is 41016.522830
# it takes 40.834 second multiple_ant_colony_system running
#
#
# [iteration 5]: find a improved path, its distance is 37016.883067
# it takes 47.683 second multiple_ant_colony_system running
#
#
# [iteration 8]: find a improved path, its distance is 35904.636836
# it takes 68.530 second multiple_ant_colony_system running
#
#
# [iteration 10]: find a improved path, its distance is 34745.088127
# it takes 82.331 second multiple_ant_colony_system running
#
#
# [iteration 13]: find a improved path, its distance is 34612.347830
# it takes 102.342 second multiple_ant_colony_system running
#
#
# [iteration 14]: find a improved path, its distance is 33690.345854
# it takes 108.760 second multiple_ant_colony_system running
#
#
# [iteration 16]: find a improved path, its distance is 33551.682064
# it takes 121.765 second multiple_ant_colony_system running
#
#
# [iteration 18]: find a improved path, its distance is 33301.894065
# it takes 134.984 second multiple_ant_colony_system running
#
#
# [iteration 19]: find a improved path, its distance is 32864.556147
# it takes 141.304 second multiple_ant_colony_system running
#
#
# [iteration 20]: find a improved path, its distance is 32357.857453
# it takes 148.089 second multiple_ant_colony_system running
#
#
# [iteration 21]: find a improved path, its distance is 31961.435292
# it takes 155.335 second multiple_ant_colony_system running
#
#
# [iteration 26]: find a improved path, its distance is 31360.938748
# it takes 191.425 second multiple_ant_colony_system running
#
#
# [iteration 27]: find a improved path, its distance is 30511.784126
# it takes 198.435 second multiple_ant_colony_system running
#
#
# [iteration 36]: find a improved path, its distance is 29970.057586
# it takes 259.507 second multiple_ant_colony_system running
#
#
# [iteration 43]: find a improved path, its distance is 29959.350506
# it takes 308.819 second multiple_ant_colony_system running
#
#
# [iteration 44]: find a improved path, its distance is 29505.529547
# it takes 316.229 second multiple_ant_colony_system running
#
#
# [iteration 47]: find a improved path, its distance is 29490.881988
# it takes 335.764 second multiple_ant_colony_system running
#
#
# [iteration 48]: find a improved path, its distance is 29147.301921
# it takes 342.093 second multiple_ant_colony_system running
#
#
# [iteration 53]: find a improved path, its distance is 28726.564801
# it takes 376.242 second multiple_ant_colony_system running
#
#
# [iteration 56]: find a improved path, its distance is 28414.763934
# it takes 395.806 second multiple_ant_colony_system running
#
#
# [iteration 58]: find a improved path, its distance is 28386.718163
# it takes 408.417 second multiple_ant_colony_system running
#
#
# [iteration 66]: find a improved path, its distance is 28129.089292
# it takes 459.781 second multiple_ant_colony_system running
#
#
# [iteration 69]: find a improved path, its distance is 28073.675472
# it takes 480.494 second multiple_ant_colony_system running
#
#
# [iteration 71]: find a improved path, its distance is 27993.733520
# it takes 493.334 second multiple_ant_colony_system running
#
#
# [iteration 78]: find a improved path, its distance is 27869.733857
# it takes 538.321 second multiple_ant_colony_system running
#
#
# [iteration 82]: find a improved path, its distance is 27660.140456
# it takes 564.593 second multiple_ant_colony_system running
#
#
# [iteration 88]: find a improved path, its distance is 27270.760291
# it takes 597.462 second multiple_ant_colony_system running
#
#
# [iteration 90]: find a improved path, its distance is 27219.120532
# it takes 608.166 second multiple_ant_colony_system running
#
#
# [iteration 97]: find a improved path, its distance is 26925.184038
# it takes 650.652 second multiple_ant_colony_system running
#
#
# [iteration 98]: find a improved path, its distance is 26342.183141
# it takes 656.615 second multiple_ant_colony_system running
#
#
# [iteration 114]: find a improved path, its distance is 26117.471796
# it takes 745.682 second multiple_ant_colony_system running
#
#
# [iteration 127]: find a improved path, its distance is 25927.206125
# it takes 819.554 second multiple_ant_colony_system running
#
#
# [iteration 149]: find a improved path, its distance is 25761.175115
# it takes 939.620 second multiple_ant_colony_system running
#
#
# [iteration 152]: find a improved path, its distance is 25544.678711
# it takes 956.264 second multiple_ant_colony_system running
#
#
# [iteration 154]: find a improved path, its distance is 25462.103039
# it takes 968.027 second multiple_ant_colony_system running
#
#
# [iteration 165]: find a improved path, its distance is 25423.704813
# it takes 1029.629 second multiple_ant_colony_system running
#
#
# [iteration 173]: find a improved path, its distance is 25111.633223
# it takes 1073.861 second multiple_ant_colony_system running
#
#
# final best path distance is 25111.633223, number of vehicle is 77
# it takes 1218.107 second multiple_ant_colony_system running
# Results saved to aco_results_600.csv
#
# Total nodes parsed: 801
# First node: ['0', '200', '200', '0', '0', '6289', '0']
#
#
# [iteration 0]: find a improved path, its distance is 101630.961917
# it takes 14.425 second multiple_ant_colony_system running
#
#
# [iteration 1]: find a improved path, its distance is 86398.458871
# it takes 26.583 second multiple_ant_colony_system running
#
#
# [iteration 2]: find a improved path, its distance is 80199.734826
# it takes 39.379 second multiple_ant_colony_system running
#
#
# [iteration 3]: find a improved path, its distance is 75473.949530
# it takes 50.996 second multiple_ant_colony_system running
#
#
# [iteration 4]: find a improved path, its distance is 70433.841967
# it takes 62.938 second multiple_ant_colony_system running
#
#
# [iteration 6]: find a improved path, its distance is 69071.134579
# it takes 84.863 second multiple_ant_colony_system running
#
#
# [iteration 7]: find a improved path, its distance is 67331.757544
# it takes 95.992 second multiple_ant_colony_system running
#
#
# [iteration 8]: find a improved path, its distance is 65684.207951
# it takes 106.612 second multiple_ant_colony_system running
#
#
# [iteration 9]: find a improved path, its distance is 65416.412085
# it takes 117.425 second multiple_ant_colony_system running
#
#
# [iteration 10]: find a improved path, its distance is 62598.142428
# it takes 127.759 second multiple_ant_colony_system running
#
#
# [iteration 11]: find a improved path, its distance is 60897.112814
# it takes 138.995 second multiple_ant_colony_system running
#
#
# [iteration 12]: find a improved path, its distance is 58586.423722
# it takes 149.306 second multiple_ant_colony_system running
#
#
# [iteration 16]: find a improved path, its distance is 58161.225180
# it takes 190.364 second multiple_ant_colony_system running
#
#
# [iteration 18]: find a improved path, its distance is 57981.307345
# it takes 210.282 second multiple_ant_colony_system running
#
#
# [iteration 19]: find a improved path, its distance is 57767.383170
# it takes 220.265 second multiple_ant_colony_system running
#
#
# [iteration 20]: find a improved path, its distance is 56940.058710
# it takes 230.318 second multiple_ant_colony_system running
#
#
# [iteration 21]: find a improved path, its distance is 55755.937149
# it takes 239.875 second multiple_ant_colony_system running
#
#
# [iteration 25]: find a improved path, its distance is 54602.057856
# it takes 280.794 second multiple_ant_colony_system running
#
#
# [iteration 26]: find a improved path, its distance is 54539.864983
# it takes 291.001 second multiple_ant_colony_system running
#
#
# [iteration 29]: find a improved path, its distance is 54110.569349
# it takes 321.836 second multiple_ant_colony_system running
#
#
# [iteration 30]: find a improved path, its distance is 53654.463154
# it takes 332.264 second multiple_ant_colony_system running
#
#
# [iteration 31]: find a improved path, its distance is 52740.809194
# it takes 341.754 second multiple_ant_colony_system running
#
#
# [iteration 33]: find a improved path, its distance is 52486.213168
# it takes 361.342 second multiple_ant_colony_system running
#
#
# [iteration 35]: find a improved path, its distance is 52449.135212
# it takes 381.109 second multiple_ant_colony_system running
#
#
# [iteration 37]: find a improved path, its distance is 51939.820689
# it takes 400.908 second multiple_ant_colony_system running
#
#
# [iteration 39]: find a improved path, its distance is 51837.518336
# it takes 420.268 second multiple_ant_colony_system running
#
#
# [iteration 40]: find a improved path, its distance is 51798.198686
# it takes 429.630 second multiple_ant_colony_system running
#
#
# [iteration 43]: find a improved path, its distance is 51565.436807
# it takes 460.314 second multiple_ant_colony_system running
#
#
# [iteration 44]: find a improved path, its distance is 50555.532032
# it takes 470.249 second multiple_ant_colony_system running
#
#
# [iteration 51]: find a improved path, its distance is 50090.658759
# it takes 537.876 second multiple_ant_colony_system running
#
#
# [iteration 54]: find a improved path, its distance is 49480.567081
# it takes 567.944 second multiple_ant_colony_system running
#
#
# [iteration 59]: find a improved path, its distance is 48638.528467
# it takes 618.607 second multiple_ant_colony_system running
#
#
# [iteration 78]: find a improved path, its distance is 48268.598252
# it takes 759.069 second multiple_ant_colony_system running
#
#
# [iteration 85]: find a improved path, its distance is 47455.014701
# it takes 775.442 second multiple_ant_colony_system running
#
#
# [iteration 108]: find a improved path, its distance is 47235.420765
# it takes 863.025 second multiple_ant_colony_system running
#
#
# [iteration 113]: find a improved path, its distance is 47015.815334
# it takes 909.327 second multiple_ant_colony_system running
#
#
# [iteration 114]: find a improved path, its distance is 46922.226745
# it takes 920.265 second multiple_ant_colony_system running
#
#
# [iteration 115]: find a improved path, its distance is 46646.056640
# it takes 930.518 second multiple_ant_colony_system running
#
#
# [iteration 117]: find a improved path, its distance is 46582.928196
# it takes 949.525 second multiple_ant_colony_system running
#
#
# [iteration 120]: find a improved path, its distance is 46229.722326
# it takes 976.908 second multiple_ant_colony_system running
#
#
# [iteration 125]: find a improved path, its distance is 45455.253839
# it takes 1015.296 second multiple_ant_colony_system running
#
#
# [iteration 155]: find a improved path, its distance is 45197.319214
# it takes 1292.516 second multiple_ant_colony_system running
#
#
# [iteration 159]: find a improved path, its distance is 45178.168488
# it takes 1332.818 second multiple_ant_colony_system running
#
#
# [iteration 162]: find a improved path, its distance is 44859.166288
# it takes 1360.900 second multiple_ant_colony_system running
#
#
# [iteration 164]: find a improved path, its distance is 44819.413311
# it takes 1379.664 second multiple_ant_colony_system running
#
#
# [iteration 166]: find a improved path, its distance is 44286.809088
# it takes 1398.665 second multiple_ant_colony_system running
#
#
# [iteration 181]: find a improved path, its distance is 43686.381563
# it takes 1546.003 second multiple_ant_colony_system running
#
#
# final best path distance is 43686.381563, number of vehicle is 90
# it takes 1723.297 second multiple_ant_colony_system running
# Results saved to aco_results_800.csv
#
# Total nodes parsed: 1001
# First node: ['0', '250', '250', '0', '0', '7284', '0']
#
#
# [iteration 0]: find a improved path, its distance is 165286.616702
# it takes 21.745 second multiple_ant_colony_system running
#
#
# [iteration 1]: find a improved path, its distance is 141083.700588
# it takes 42.581 second multiple_ant_colony_system running
#
#
# [iteration 2]: find a improved path, its distance is 130018.912419
# it takes 61.900 second multiple_ant_colony_system running
#
#
# [iteration 3]: find a improved path, its distance is 122658.217935
# it takes 80.655 second multiple_ant_colony_system running
#
#
# [iteration 4]: find a improved path, its distance is 119252.351696
# it takes 99.694 second multiple_ant_colony_system running
#
#
# [iteration 5]: find a improved path, its distance is 111802.177340
# it takes 117.990 second multiple_ant_colony_system running
#
#
# [iteration 7]: find a improved path, its distance is 109526.117338
# it takes 153.166 second multiple_ant_colony_system running
#
#
# [iteration 8]: find a improved path, its distance is 106632.241846
# it takes 171.754 second multiple_ant_colony_system running
#
#
# [iteration 9]: find a improved path, its distance is 105067.217544
# it takes 188.337 second multiple_ant_colony_system running
#
#
# [iteration 10]: find a improved path, its distance is 102804.324372
# it takes 202.925 second multiple_ant_colony_system running
#
#
# [iteration 11]: find a improved path, its distance is 101973.048290
# it takes 219.947 second multiple_ant_colony_system running
#
#
# [iteration 12]: find a improved path, its distance is 101219.488162
# it takes 239.343 second multiple_ant_colony_system running
#
#
# [iteration 13]: find a improved path, its distance is 98553.878683
# it takes 256.180 second multiple_ant_colony_system running
#
#
# [iteration 14]: find a improved path, its distance is 95608.566314
# it takes 273.381 second multiple_ant_colony_system running
#
#
# [iteration 16]: find a improved path, its distance is 93544.628982
# it takes 306.778 second multiple_ant_colony_system running
#
#
# [iteration 17]: find a improved path, its distance is 91822.883055
# it takes 323.118 second multiple_ant_colony_system running
#
#
# [iteration 18]: find a improved path, its distance is 91803.007141
# it takes 339.062 second multiple_ant_colony_system running
#
#
# [iteration 19]: find a improved path, its distance is 89872.905783
# it takes 354.415 second multiple_ant_colony_system running
#
#
# [iteration 21]: find a improved path, its distance is 89385.781385
# it takes 385.536 second multiple_ant_colony_system running
#
#
# [iteration 22]: find a improved path, its distance is 88595.546265
# it takes 403.023 second multiple_ant_colony_system running
#
#
# [iteration 23]: find a improved path, its distance is 86524.575232
# it takes 419.009 second multiple_ant_colony_system running
#
#
# [iteration 25]: find a improved path, its distance is 85908.193766
# it takes 451.852 second multiple_ant_colony_system running
#
#
# [iteration 26]: find a improved path, its distance is 84909.503510
# it takes 467.611 second multiple_ant_colony_system running
#
#
# [iteration 30]: find a improved path, its distance is 83344.671906
# it takes 525.946 second multiple_ant_colony_system running
#
#
# [iteration 32]: find a improved path, its distance is 83325.519175
# it takes 552.265 second multiple_ant_colony_system running
#
#
# [iteration 33]: find a improved path, its distance is 81865.055022
# it takes 567.443 second multiple_ant_colony_system running
#
#
# [iteration 37]: find a improved path, its distance is 79509.077045
# it takes 624.955 second multiple_ant_colony_system running
#
#
# [iteration 42]: find a improved path, its distance is 79176.204169
# it takes 697.370 second multiple_ant_colony_system running
#
#
# [iteration 45]: find a improved path, its distance is 78355.082221
# it takes 739.437 second multiple_ant_colony_system running
#
#
# [iteration 52]: find a improved path, its distance is 77887.867431
# it takes 856.884 second multiple_ant_colony_system running
#
#
# [iteration 56]: find a improved path, its distance is 77793.252007
# it takes 914.851 second multiple_ant_colony_system running
#
#
# [iteration 58]: find a improved path, its distance is 77655.726769
# it takes 943.811 second multiple_ant_colony_system running
#
#
# [iteration 60]: find a improved path, its distance is 77351.709788
# it takes 970.676 second multiple_ant_colony_system running
#
#
# [iteration 63]: find a improved path, its distance is 75993.996503
# it takes 1011.640 second multiple_ant_colony_system running
#
#
# [iteration 67]: find a improved path, its distance is 75794.297802
# it takes 1072.370 second multiple_ant_colony_system running
#
#
# [iteration 76]: find a improved path, its distance is 73709.635925
# it takes 1205.800 second multiple_ant_colony_system running
#
#
# [iteration 92]: find a improved path, its distance is 72523.208992
# it takes 1447.010 second multiple_ant_colony_system running
#
#
# [iteration 101]: find a improved path, its distance is 71963.611880
# it takes 1559.834 second multiple_ant_colony_system running
#
#
# [iteration 103]: find a improved path, its distance is 71813.157853
# it takes 1584.793 second multiple_ant_colony_system running
#
#
# [iteration 104]: find a improved path, its distance is 71781.177118
# it takes 1597.363 second multiple_ant_colony_system running
#
#
# [iteration 111]: find a improved path, its distance is 71007.851310
# it takes 1685.413 second multiple_ant_colony_system running
#
#
# [iteration 117]: find a improved path, its distance is 70501.453412
# it takes 1767.023 second multiple_ant_colony_system running
#
#
# [iteration 123]: find a improved path, its distance is 70013.569774
# it takes 1847.111 second multiple_ant_colony_system running
#
#
# [iteration 135]: find a improved path, its distance is 69303.882797
# it takes 2007.142 second multiple_ant_colony_system running
#
#
# [iteration 147]: find a improved path, its distance is 69106.051076
# it takes 2166.499 second multiple_ant_colony_system running
#
#
# [iteration 157]: find a improved path, its distance is 68262.639805
# it takes 2300.285 second multiple_ant_colony_system running
#
#
# [iteration 167]: find a improved path, its distance is 68092.807062
# it takes 2436.482 second multiple_ant_colony_system running
#
#
# [iteration 182]: find a improved path, its distance is 66167.364556
# it takes 2637.221 second multiple_ant_colony_system running
#
#
# [iteration 198]: find a improved path, its distance is 66131.428331
# it takes 2853.686 second multiple_ant_colony_system running
#
#
# final best path distance is 66131.428331, number of vehicle is 119
# it takes 2867.833 second multiple_ant_colony_system running
# Results saved to aco_results_1000.csv

# %%
result_file = './results/param4/r1/aco_results_25.csv'
df = pd.read_csv(result_file)

plt.figure(figsize=(12, 6))

plt.plot(df['iteration'], df['best_cost'], 
         linewidth=2, color='blue', label='Best Cost')

plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Cost (Distance)', fontsize=12)
plt.title('ACO Convergence - Best Cost over Iterations', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
